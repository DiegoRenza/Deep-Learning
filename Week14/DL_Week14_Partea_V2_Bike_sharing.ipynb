# %% [markdown]
# https://archive.ics.uci.edu/dataset/275/bike+sharing+dataset

# %%
# prompt: Descarga el archivo https://archive.ics.uci.edu/static/public/275/bike+sharing+dataset.zip

# %%
import pandas as pd

# %% [markdown]
# #Leer y descomprimir dataset

# %%
# !wget https://archive.ics.uci.edu/static/public/275/bike+sharing+dataset.zip

# !unzip bike+sharing+dataset.zip
# Out:
# --2025-04-29 13:48:37--  https://archive.ics.uci.edu/static/public/275/bike+sharing+dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘bike+sharing+dataset.zip’
#
# bike+sharing+datase     [   <=>              ] 273.43K   404KB/s    in 0.7s
#
# 2025-04-29 13:48:38 (404 KB/s) - ‘bike+sharing+dataset.zip’ saved [279992]
#
# Archive:  bike+sharing+dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv

# %%
data_file = '/content/hour.csv'
data = pd.read_csv(data_file)
print(data)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# 1               0           1  0.22  0.2727  0.80     0.0000       8
# 2               0           1  0.22  0.2727  0.80     0.0000       5
# 3               0           1  0.24  0.2879  0.75     0.0000       3
# 4               0           1  0.24  0.2879  0.75     0.0000       0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 0              13   16
# 1              32   40
# 2              27   32
# 3              10   13
# 4               1    1
# ...           ...  ...
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49
#
# [17379 rows x 17 columns]

# %%
data.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
# Integer-location based indexing (iloc): para separar los datos en entrada y salida
# Reemplazar NAn con el valor medio
inputs, outputs = data.iloc[:, 2:16], data.iloc[:, 16]
inputs = inputs.fillna(inputs.mean())
print(inputs)
print(outputs)
# Out:
#        season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1   0     1   0        0        6           0           1  0.24
# 1           1   0     1   1        0        6           0           1  0.22
# 2           1   0     1   2        0        6           0           1  0.22
# 3           1   0     1   3        0        6           0           1  0.24
# 4           1   0     1   4        0        6           0           1  0.24
# ...       ...  ..   ...  ..      ...      ...         ...         ...   ...
# 17374       1   1    12  19        0        1           1           2  0.26
# 17375       1   1    12  20        0        1           1           2  0.26
# 17376       1   1    12  21        0        1           1           1  0.26
# 17377       1   1    12  22        0        1           1           1  0.26
# 17378       1   1    12  23        0        1           1           1  0.26
#
#         atemp   hum  windspeed  casual  registered
# 0      0.2879  0.81     0.0000       3          13
# 1      0.2727  0.80     0.0000       8          32
# 2      0.2727  0.80     0.0000       5          27
# 3      0.2879  0.75     0.0000       3          10
# 4      0.2879  0.75     0.0000       0           1
# ...       ...   ...        ...     ...         ...
# 17374  0.2576  0.60     0.1642      11         108
# 17375  0.2576  0.60     0.1642       8          81
# 17376  0.2576  0.60     0.1642       7          83
# 17377  0.2727  0.56     0.1343      13          48
# 17378  0.2727  0.65     0.1343      12          37
#
# [17379 rows x 14 columns]
# 0         16
# 1         40
# 2         32
# 3         13
# 4          1
#         ...
# 17374    119
# 17375     89
# 17376     90
# 17377     61
# 17378     49
# Name: cnt, Length: 17379, dtype: int64

# %%
inputs.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered
# 0  0.2879  0.81        0.0       3          13
# 1  0.2727  0.80        0.0       8          32
# 2  0.2727  0.80        0.0       5          27
# 3  0.2879  0.75        0.0       3          10
# 4  0.2879  0.75        0.0       0           1

# %%
outputs.head()
# Out:
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: cnt, dtype: int64

# %%
#Convertir a Numpy
X = inputs.to_numpy()
y = outputs.to_numpy()

# %% [markdown]
# **Graficar la temperatura en el tiempo para todas las muestras**

# %%
from matplotlib import pyplot as plt
plt.plot(range(len(y)), y)

# %% [markdown]
# **Graficar la temperatura para los primeros 10 días (240 muestras)**

# %%
# Analizar la periodicidad de los datos, por ejemplo en los últimos 4 días

plt.plot(range(240), y[:240])

# %% [markdown]
# **Distribución de datos**
#
# Asegurarse que validación y test son datos recientes
#
# Train: 50%
# Val: 0.25
# Test: 0.25

# %%
No_train = 12166
No_val = 2607
No_test = 2606

# %% [markdown]
# **Estandarización de datos**

# %%
"""
# Train
media = X[0:No_train].mean(axis=0)
std = X[0:No_train].std(axis=0)

X = (X - media)/std
"""

# %% [markdown]
# # Lectura por lotes

# %%
# Tomar sólo un dato cada hora
sampling_rate = 1

# Utilizar los datos de los últimos 5 días (120 horas)
sequence_length = 72

# Se realizará la predicción para el contador de uso 1 horas después
delay = sampling_rate * (sequence_length + 1 - 1)

# Tamaño del lote
batch_size = 256

# %%
# Los datos de entrenamiento se leen desde el inicio (start
# index) hasta el 50% de los datos (end index)

# La aleatorización se realiza sólo al interior del batch

import keras

train_dataset = keras.utils.timeseries_dataset_from_array(
    X[:-delay],
    targets=y[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=0,
    end_index=No_train)

# %%
# Los datos de entrenamiento se leen desde el 50% (start
# index) hasta el 75% de los datos (end index)

# La aleatorización se realiza sólo al interior del batch

val_dataset = keras.utils.timeseries_dataset_from_array(
    X[:-delay],
    targets=y[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=No_train,
    end_index=No_train + No_val)

# %%
# Los datos de entrenamiento se leen desde el 75% (start
# index) hasta el 100% de los datos (end index)

# La aleatorización se realiza sólo al interior del batch

test_dataset = keras.utils.timeseries_dataset_from_array(
    X[:-delay],
    targets=y[delay:],
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=batch_size,
    start_index=No_train + No_val)

# %% [markdown]
# # Dimensiones de los datos

# %%
for samples, targets in train_dataset:
  print("samples shape:", samples.shape)
  print("targets shape:", targets.shape)
  break
# Out:
# samples shape: (256, 72, 14)
# targets shape: (256,)

# %% [markdown]
# # Modelo base con MLP

# %%
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv1D, Dense, MaxPooling1D, Input, GlobalAveragePooling1D, LSTM, Dropout, Bidirectional

model_MLP = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    #Flatten(),
    Dense(128, activation="relu"),
    Dense(1)
])

model_MLP.compile(
    optimizer='rmsprop',
    loss='mse',
    metrics=['mae']
)

history_MLP = model_MLP.fit(train_dataset,
                    epochs=100,
                    validation_data=val_dataset,
                    #callbacks=callbacks
                    )

print(f"MAE (Test): {model_MLP.evaluate(test_dataset)[1]:.2f}")
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 39635.0078 - mae: 141.5048 - val_loss: 80161.7891 - val_mae: 216.2470
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 31777.2734 - mae: 128.7463 - val_loss: 73970.9688 - val_mae: 208.2958
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 28963.1074 - mae: 124.1204 - val_loss: 72588.4609 - val_mae: 204.6985
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 26574.9629 - mae: 120.5639 - val_loss: 66203.2578 - val_mae: 196.7607
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 25071.4492 - mae: 119.3493 - val_loss: 68131.5312 - val_mae: 198.7275
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss:
100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 22864.8848 - mae: 118.6683 - val_loss: 61381.7422 - val_mae: 189.7788
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 49143.1094 - mae: 167.8843
# MAE (Test): 167.52

# %% [markdown]
# **Ver curvas de rendimiento**

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history_MLP.history['mae'])
plt.plot(history_MLP.history['val_mae'])
plt.title('Mean Absolute error')
plt.ylabel('MAE')
plt.xlabel('Época')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Modelo Conv 1D

# %%
model_Conv1D = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    Conv1D(32, 24, activation="relu"),
    MaxPooling1D(2),
    Conv1D(32, 12, activation="relu"),
    MaxPooling1D(2),
    Conv1D(32, 6, activation="relu"),
    GlobalAveragePooling1D(),
    Dense(1)
])

model_Conv1D.compile(
    optimizer='rmsprop',
    loss='mse',
    metrics=['mae']
)

history_Conv1D = model_Conv1D.fit(train_dataset,
                    epochs=100,
                    validation_data=val_dataset,
                    #callbacks=callbacks
                    )

#model = keras.models.load_model("MODEL_CONV1D.h5")

print(f"MAE (Test): {model_Conv1D.evaluate(test_dataset)[1]:.2f}")
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - loss: 17252.6484 - mae: 91.3537 - val_loss: 17617.9668 - val_mae: 89.1042
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 7706.7998 - mae: 60.8875 - val_loss: 15018.7520 - val_mae: 88.5333
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6962.3818 - mae: 58.0181 - val_loss: 17156.8027 - val_mae: 99.9891
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 6654.7432 - mae: 55.9261 - val_loss: 18654.9375 - val_mae: 106.2540
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 6204.3545 - mae: 54.1884 - val_loss: 13590.1562 - val_mae: 85.0263
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5501.5308 - mae: 50.0334 - val_loss: 11284.7852 - val_mae: 76.9059
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 5292.8374 - mae: 49.8354 - val_loss: 10481.4590 - val_mae: 72.9734
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4923.1621 - mae: 47.8281 - val_loss: 10912.7383 - val_mae: 73.7439
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 4850.8735 - mae: 46.8335 - val_loss: 8242.2207 - val_mae: 64.1469
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4706.3965 - mae: 46.3777 - val_loss: 8216.4688 - val_mae: 60.7099
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 4496.6543 - mae: 44.6127 - val_loss: 12022.7930 - val_mae: 83.1757
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4149.2983 - mae: 42.7702 - val_loss: 6584.4028 - val_mae: 52.9229
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4056.1814 - mae: 42.2473 - val_loss: 10644.7061 - val_mae: 73.6802
# Epoch 14/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4123.9639 - mae: 42.8647 - val_loss: 6337.1196 - val_mae: 52.8590
# Epoch 15/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 3769.6292 - mae: 41.0579 - val_loss: 8126.7769 - val_mae: 64.5661
# Epoch 16/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3658.1023 - mae: 39.9931 - val_loss: 7681.8164 - val_mae: 61.3882
# Epoch 17/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3529.1670 - mae: 39.1284 - val_loss: 8169.8423 - val_mae: 64.0190
# Epoch 18/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3719.8523 - mae: 40.4731 - val_loss: 5993.5654 - val_mae: 51.4019
# Epoch 19/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3274.7253 - mae: 37.7442 - val_loss: 6663.5605 - val_mae: 56.8974
# Epoch 20/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 3242.0916 - mae: 37.4093 - val_loss: 6394.9731 - val_mae: 54.1053
# Epoch 21/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 3179.5776 - mae: 36.8427 - val_loss: 7728.0869 - val_mae: 61.4708
# Epoch 22/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3127.3660 - mae: 36.7269 - val_loss: 6813.7036 - val_mae: 57.1036
# Epoch 23/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 3038.3643 - mae: 36.1583 - val_loss: 8123.4165 - val_mae: 61.7719
# Epoch 24/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3077.4185 - mae: 36.7236 - val_loss: 5990.0679 - val_mae: 52.7127
# Epoch 25/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 2954.1929 - mae: 36.0987 - val_loss: 8258.6533 - val_mae: 64.7379
# Epoch 26/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 
100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1387.8569 - mae: 25.4713 - val_loss: 5679.4907 - val_mae: 48.4306
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1338.8168 - mae: 24.9041 - val_loss: 6002.0664 - val_mae: 49.7161
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1264.4313 - mae: 24.2964 - val_loss: 6056.8525 - val_mae: 52.0834
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1293.3124 - mae: 24.4544 - val_loss: 6493.4575 - val_mae: 52.2318
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1329.2377 - mae: 24.6513 - val_loss: 7690.9067 - val_mae: 60.8428
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1316.4009 - mae: 24.8333 - val_loss: 5861.2686 - val_mae: 50.5003
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1326.5896 - mae: 25.2095 - val_loss: 8950.6660 - val_mae: 61.9500
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1276.6719 - mae: 24.0472 - val_loss: 9105.5176 - val_mae: 68.2606
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 1227.7629 - mae: 23.9580 - val_loss: 5546.7578 - val_mae: 48.4975
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1216.0985 - mae: 23.9985 - val_loss: 7300.1089 - val_mae: 59.9708
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1233.6102 - mae: 23.9652 - val_loss: 7184.2573 - val_mae: 58.8521
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 1180.9657 - mae: 23.5460 - val_loss: 9021.6016 - val_mae: 64.8733
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1185.4313 - mae: 23.4900 - val_loss: 6153.2100 - val_mae: 51.4699
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5687.4707 - mae: 48.8638
# MAE (Test): 49.64

# %% [markdown]
# **Ver curvas de rendimiento**

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history_Conv1D.history['mae'])
plt.plot(history_Conv1D.history['val_mae'])
plt.title('Mean Absolute error')
plt.ylabel('MAE')
plt.xlabel('Época')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Modelo  LSTM

# %%
model_LSTM = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    LSTM(128),
    Dense(1)
])

model_LSTM.compile(
    optimizer='rmsprop',
    loss='mse',
    metrics=['mae']
)

history_LSTM = model_LSTM.fit(train_dataset,
                    epochs=100,
                    validation_data=val_dataset,
                    #callbacks=callbacks
                              )

print(f"Test MAE: {model_LSTM.evaluate(test_dataset)[1]:.2f}")
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 45783.7773 - mae: 153.3167 - val_loss: 121169.2891 - val_mae: 267.7224
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 42192.6484 - mae: 143.8381 - val_loss: 118132.3125 - val_mae: 263.2057
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 40727.5547 - mae: 139.9011 - val_loss: 115343.4219 - val_mae: 258.8981
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 39212.7891 - mae: 135.8291 - val_loss: 112446.0469 - val_mae: 254.3277
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 38182.7227 - mae: 133.0220 - val_loss: 109778.0547 - val_mae: 249.9951
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 36498.6680 - mae: 127.9968 - val_loss: 107175.0625 - val_mae: 245.7846
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 34989.4922 - mae: 123.9147 - val_loss: 104522.0156 - val_mae: 241.5326
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 34187.4102 - mae: 121.0162 - val_loss: 101890.0000 - val_mae: 237.2897
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 32858.7617 - mae: 117.1418 - val_loss: 99405.8047 - val_mae: 233.2598
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 31493.7617 - mae: 113.6385 - val_loss: 96961.1953 - val_mae: 229.3593
# Epoch 11/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 29776.9707 - mae: 109.3717 - val_loss: 94467.4922 - val_mae: 225.1799
# Epoch 12/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 28512.8477 - mae: 105.8116 - val_loss: 91998.8438 - val_mae: 221.2389
# Epoch 13/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss:
100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 2217.8340 - mae: 25.5810 - val_loss: 13706.2148 - val_mae: 64.9364
# Epoch 78/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 2225.8638 - mae: 25.5178 - val_loss: 13163.6436 - val_mae: 63.8558
# Epoch 79/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 2143.9724 - mae: 25.4116 - val_loss: 13076.8340 - val_mae: 63.9278
# Epoch 80/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1981.0042 - mae: 24.6229 - val_loss: 12153.3203 - val_mae: 60.6376
# Epoch 81/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 1924.6533 - mae: 24.3275 - val_loss: 12077.6895 - val_mae: 60.4540
# Epoch 82/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1916.2781 - mae: 24.2502 - val_loss: 11853.9014 - val_mae: 59.5716
# Epoch 83/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1896.1287 - mae: 24.2682 - val_loss: 11453.6914 - val_mae: 59.0595
# Epoch 84/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 1769.3184 - mae: 23.5815 - val_loss: 11382.7432 - val_mae: 59.3406
# Epoch 85/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 1706.2113 - mae: 23.5747 - val_loss: 10919.6895 - val_mae: 56.9982
# Epoch 86/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1648.7429 - mae: 23.2670 - val_loss: 10364.1211 - val_mae: 56.4364
# Epoch 87/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1512.7656 - mae: 22.6838 - val_loss: 10128.1377 - val_mae: 56.8748
# Epoch 88/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1602.8706 - mae: 23.1326 - val_loss: 9686.5303 - val_mae: 54.6901
# Epoch 89/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1523.0275 - mae: 22.7745 - val_loss: 9445.9082 - val_mae: 55.2371
# Epoch 90/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1517.7026 - mae: 22.5158 - val_loss: 9252.4502 - val_mae: 53.0020
# Epoch 91/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 1476.1191 - mae: 22.3968 - val_loss: 8875.8594 - val_mae: 51.7539
# Epoch 92/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1393.6370 - mae: 21.9049 - val_loss: 8990.4531 - val_mae: 52.2157
# Epoch 93/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1383.8214 - mae: 21.8181 - val_loss: 8674.0879 - val_mae: 51.6106
# Epoch 94/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 1374.2670 - mae: 21.9200 - val_loss: 8294.1006 - val_mae: 50.7774
# Epoch 95/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1385.6433 - mae: 21.8478 - val_loss: 8101.9473 - val_mae: 49.9056
# Epoch 96/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1296.0293 - mae: 21.4979 - val_loss: 7761.7798 - val_mae: 49.4449
# Epoch 97/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 1265.2429 - mae: 21.2381 - val_loss: 8377.7959 - val_mae: 53.7834
# Epoch 98/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1296.0540 - mae: 22.1552 - val_loss: 7699.8857 - val_mae: 49.8216
# Epoch 99/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 1173.8075 - mae: 20.7197 - val_loss: 7241.0449 - val_mae: 47.8693
# Epoch 100/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 1178.3862 - mae: 20.7125 - val_loss: 7323.0859 - val_mae: 47.2155
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5537.3940 - mae: 39.6856
# Test MAE: 41.00

# %% [markdown]
# **Ver curvas de rendimiento**

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history_LSTM.history['mae'])
plt.plot(history_LSTM.history['val_mae'])
plt.title('Mean Absolute error')
plt.ylabel('MAE')
plt.xlabel('Época')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Modelo  LSTM 2

# %%
model_LSTM2 = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    LSTM(128, recurrent_dropout=0.25),
    Dropout(0.5),
    Dense(1)
])

model_LSTM2.compile(
    optimizer='rmsprop',
    loss='mse',
    metrics=['mae']
)

history_LSTM2 = model_LSTM2.fit(train_dataset,
                    epochs=50,
                    validation_data=val_dataset,
                    #callbacks=callbacks
                              )

print(f"Test MAE: {model_LSTM2.evaluate(test_dataset)[1]:.2f}")
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 15s 259ms/step - loss: 46786.9258 - mae: 156.5886 - val_loss: 127322.5078 - val_mae: 277.6188
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 243ms/step - loss: 45915.9805 - mae: 152.8919 - val_loss: 125946.7266 - val_mae: 275.2473
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 234ms/step - loss: 45857.0078 - mae: 151.9146 - val_loss: 124963.9375 - val_mae: 273.6810
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 234ms/step - loss: 44344.5391 - mae: 149.7968 - val_loss: 124060.7578 - val_mae: 272.2674
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 240ms/step - loss: 44334.8516 - mae: 148.7571 - val_loss: 123307.3594 - val_mae: 271.0872
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 256ms/step - loss: 43981.6484 - mae: 148.7195 - val_loss: 122565.7891 - val_mae: 269.9331
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 254ms/step - loss: 43605.9219 - mae: 146.8801 - val_loss: 121821.9297 - val_mae: 268.7702
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 241ms/step - loss: 42845.5273 - mae: 145.1077 - val_loss: 121086.1797 - val_mae: 267.6178
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 242ms/step - loss: 43106.8906 - mae: 145.3637 - val_loss: 120356.4297 - val_mae: 266.4760
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 246ms/step - loss: 42485.0508 - mae: 144.1927 - val_loss: 119626.7344 - val_mae: 265.3354
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 247ms/step - loss: 41934.9492 - mae: 142.7344 - val_loss: 118899.7969 - val_mae: 264.1902
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 241ms/step - loss: 41771.3984 - mae: 141.5111 - val_loss: 118179.4922 - val_mae: 263.0729
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - loss: 40896.7031 - mae: 139.9150 - val_loss: 117456.4688 - val_mae: 261.9248
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 245ms/step - loss: 40664.4180 - mae: 139.3115 - val_loss: 116736.4688 - val_mae: 260.7927
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 243ms/step - loss: 40433.5938 - mae: 138.1935 - val_loss: 116030.3984 - val_mae: 259.6685
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 257ms/step - loss: 39671.9961 - mae: 136.6880 - val_loss: 115313.5391 - val_mae: 258.5302
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 12s 244ms/step - loss: 39072.8672 - mae: 135.5145 - val_loss: 114609.1641 - val_mae: 257.4035
# Epoch 18/50
# 42/48 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 39468.0312 - mae: 135.6189
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-209672159dba> in <cell line: 0>()
#      12 )
#      13
# ---> 14 history_LSTM2 = model_LSTM2.fit(train_dataset,
#      15                     epochs=50,
#      16                     validation_data=val_dataset,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def plotmodelhistory(history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(history_LSTM.history['mae'])
    axs[0].plot(history_LSTM.history['val_mae'])
    axs[0].set_title('Mean Absolute error (LSTM1)')
    axs[0].set_ylabel('MAE')
    axs[0].set_xlabel('Época')
    axs[0].legend(['Train', 'Validate'], loc='upper right')
    # summarize history for loss
    axs[1].plot(history_LSTM2.history['mae'])
    axs[1].plot(history_LSTM2.history['val_mae'])
    axs[1].set_title('Mean Absolute error (LSTM1)')
    axs[1].set_ylabel('MAE')
    axs[1].set_xlabel('Época')
    axs[1].legend(['Train', 'Validate'], loc='upper right')
    plt.show()

# list all data in history
#print(history.history.keys())

plotmodelhistory(history)

# %%
model_LSTM3 = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    LSTM(32, recurrent_dropout=0.25, return_sequences=True),
    LSTM(32, recurrent_dropout=0.5),
    Dropout(0.5),
    Dense(1)
])

# %%
model_LSTM4 = Sequential([
    Input(shape=(sequence_length, X.shape[-1])),
    Bidirectional(LSTM(32)),
    Dense(1)
])
