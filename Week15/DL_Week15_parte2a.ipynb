# %% [markdown]
# # Text document Classification (Dataset)
#
# https://www.kaggle.com/datasets/jensenbaxter/10dataset-text-document-classification
#
# *   10 clases
# *   1000 muestras de entrenamiento

# %%
import zipfile
with zipfile.ZipFile('/content/Dataset_text.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Dataset_text/')

# %%
from tensorflow import keras
batch_size = 32

train_ds = keras.utils.text_dataset_from_directory(
    "/content/Dataset_text",
    batch_size=batch_size,
    validation_split=0.2,
    label_mode="categorical",
    seed = 2023,
    subset="training",
)
# Out:
# Found 1000 files belonging to 10 classes.
# Using 800 files for training.

# %%
val_ds = keras.utils.text_dataset_from_directory(
    "/content/Dataset_text",
    batch_size=batch_size,
    validation_split=0.2,
    label_mode="categorical",
    seed = 2023,
    subset="validation",
)
# Out:
# Found 1000 files belonging to 10 classes.
# Using 200 files for validation.

# %% [markdown]
# # Data preparation

# %%
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization

# No se utilizan ngrams (none)
max_length = 600
max_tokens = 20000
text_vectorization = TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,    # Limitar la entrada a 600 palabras
)

# Extraer solo el texto (features) de los datos de entrada para calcular el vocabulario
text_only_train_ds = train_ds.map(lambda x, y: x)

text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Input, Dropout, Bidirectional


inputs = Input(shape=(None,), dtype="int64")
embedded = tf.keras.ops.one_hot(inputs, num_classes=max_tokens)

x = Bidirectional(layers.LSTM(32))(embedded)
x = Dropout(0.5)(x)
outputs = Dense(10, activation="softmax")(x)

model_LSTM = keras.Model(inputs, outputs)

model_LSTM.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model_LSTM.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, None)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ one_hot (OneHot)                │ (None, None, 20000)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 64)             │     5,128,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,129,098 (19.57 MB)
#  Trainable params: 5,129,098 (19.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Entrenamiento

# %%
# Utilización de caché
model_LSTM.fit(
    int_train_ds,
    validation_data=int_val_ds,
    epochs=20,
    #callbacks=callbacks
    )
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.1386 - loss: 2.2993 - val_accuracy: 0.3250 - val_loss: 2.2839
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.2985 - loss: 2.2605 - val_accuracy: 0.1950 - val_loss: 2.1787
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - accuracy: 0.2456 - loss: 2.0758 - val_accuracy: 0.2700 - val_loss: 2.0176
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - accuracy: 0.2836 - loss: 2.0054 - val_accuracy: 0.3400 - val_loss: 1.9082
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 352ms/step - accuracy: 0.3191 - loss: 1.9035 - val_accuracy: 0.2400 - val_loss: 2.0774
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 339ms/step - accuracy: 0.2947 - loss: 1.8749 - val_accuracy: 0.3650 - val_loss: 1.7880
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 340ms/step - accuracy: 0.2821 - loss: 1.8097 - val_accuracy: 0.3600 - val_loss: 1.7115
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.3147 - loss: 1.7291 - val_accuracy: 0.3350 - val_loss: 1.6971
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 341ms/step - accuracy: 0.3650 - loss: 1.7111 - val_accuracy: 0.3800 - val_loss: 1.6582
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 357ms/step - accuracy: 0.3213 - loss: 1.6358 - val_accuracy: 0.4500 - val_loss: 1.6399
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.3915 - loss: 1.5462 - val_accuracy: 0.3500 - val_loss: 1.6679
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 347ms/step - accuracy: 0.4178 - loss: 1.5694 - val_accuracy: 0.4850 - val_loss: 1.5874
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.4462 - loss: 1.4903 - val_accuracy: 0.3500 - val_loss: 1.7059
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - accuracy: 0.4928 - loss: 1.4221 - val_accuracy: 0.4200 - val_loss: 1.5955
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - accuracy: 0.5210 - loss: 1.3365 - val_accuracy: 0.5600 - val_loss: 1.3228
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.5341 - loss: 1.2748 - val_accuracy: 0.5500 - val_loss: 1.2909
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.5480 - loss: 1.2451 - val_accuracy: 0.6000 - val_loss: 1.2534
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 357ms/step - accuracy: 0.5709 - loss: 1.2621 - val_accuracy: 0.6600 - val_loss: 1.1874
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 358ms/step - accuracy: 0.5761 - loss: 1.1720 - val_accuracy: 0.6050 - val_loss: 1.1974
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 357ms/step - accuracy: 0.6594 - loss: 1.0519 - val_accuracy: 0.5200 - val_loss: 1.3163

# %% [markdown]
# #Evaluación del modelo
#
# Sobre datos test
