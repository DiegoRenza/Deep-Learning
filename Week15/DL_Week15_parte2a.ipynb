# %% [markdown]
# # Text document Classification (Dataset)
#
# https://www.kaggle.com/datasets/jensenbaxter/10dataset-text-document-classification
#
# *   10 clases
# *   1000 muestras de entrenamiento

# %%
import zipfile
with zipfile.ZipFile('/content/Dataset_text.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/Dataset_text/')

# %%
from tensorflow import keras
batch_size = 32

train_ds = keras.utils.text_dataset_from_directory(
    "/content/Dataset_text",
    batch_size=batch_size,
    validation_split=0.2,
    label_mode="categorical",
    seed = 2023,
    subset="training",
)
# Out:
# Found 1000 files belonging to 10 classes.
# Using 800 files for training.

# %%
val_ds = keras.utils.text_dataset_from_directory(
    "/content/Dataset_text",
    batch_size=batch_size,
    validation_split=0.2,
    label_mode="categorical",
    seed = 2023,
    subset="validation",
)
# Out:
# Found 1000 files belonging to 10 classes.
# Using 200 files for validation.

# %% [markdown]
# # Data preparation

# %%
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization

# No se utilizan ngrams (none)
max_length = 600
max_tokens = 20000
text_vectorization = TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,    # Limitar la entrada a 600 palabras
)

# Extraer solo el texto (features) de los datos de entrada para calcular el vocabulario
text_only_train_ds = train_ds.map(lambda x, y: x)

text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Input, Dropout, Bidirectional


inputs = Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)

x = Bidirectional(layers.LSTM(32))(embedded)
x = Dropout(0.5)(x)
outputs = Dense(10, activation="softmax")(x)

model_LSTM = keras.Model(inputs, outputs)

model_LSTM.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model_LSTM.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot (TFOpLambda)     (None, None, 20000)       0
#
#  bidirectional (Bidirection  (None, 64)                5128448
#  al)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 5129098 (19.57 MB)
# Trainable params: 5129098 (19.57 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Entrenamiento

# %%
# Utilización de caché
model_LSTM.fit(
    int_train_ds,
    validation_data=int_val_ds,
    epochs=20,
    #callbacks=callbacks
    )
# Out:
# Epoch 1/20
# 25/25 [==============================] - 13s 289ms/step - loss: 2.2987 - accuracy: 0.1300 - val_loss: 2.2928 - val_accuracy: 0.1850
# Epoch 2/20
# 25/25 [==============================] - 6s 233ms/step - loss: 2.2663 - accuracy: 0.1838 - val_loss: 2.2220 - val_accuracy: 0.2050
# Epoch 3/20
# 25/25 [==============================] - 6s 231ms/step - loss: 2.1551 - accuracy: 0.1950 - val_loss: 2.1117 - val_accuracy: 0.1900
# Epoch 4/20
# 25/25 [==============================] - 6s 257ms/step - loss: 2.0477 - accuracy: 0.2188 - val_loss: 2.0787 - val_accuracy: 0.1850
# Epoch 5/20
# 25/25 [==============================] - 6s 233ms/step - loss: 1.9250 - accuracy: 0.2725 - val_loss: 2.0132 - val_accuracy: 0.2000
# Epoch 6/20
# 25/25 [==============================] - 6s 237ms/step - loss: 1.8461 - accuracy: 0.2688 - val_loss: 1.8704 - val_accuracy: 0.2450
# Epoch 7/20
# 25/25 [==============================] - 6s 234ms/step - loss: 1.7703 - accuracy: 0.3075 - val_loss: 1.7521 - val_accuracy: 0.2850
# Epoch 8/20
# 25/25 [==============================] - 6s 256ms/step - loss: 1.8044 - accuracy: 0.2962 - val_loss: 1.8408 - val_accuracy: 0.2250
# Epoch 9/20
# 25/25 [==============================] - 6s 236ms/step - loss: 1.6942 - accuracy: 0.3150 - val_loss: 1.7521 - val_accuracy: 0.2950
# Epoch 10/20
# 25/25 [==============================] - 6s 236ms/step - loss: 1.6343 - accuracy: 0.3500 - val_loss: 1.8842 - val_accuracy: 0.4800
# Epoch 11/20
# 25/25 [==============================] - 6s 236ms/step - loss: 1.5770 - accuracy: 0.4162 - val_loss: 1.5847 - val_accuracy: 0.3800
# Epoch 12/20
# 25/25 [==============================] - 6s 260ms/step - loss: 1.5404 - accuracy: 0.3887 - val_loss: 1.5869 - val_accuracy: 0.5100
# Epoch 13/20
# 25/25 [==============================] - 6s 234ms/step - loss: 1.4653 - accuracy: 0.4675 - val_loss: 1.4883 - val_accuracy: 0.4400
# Epoch 14/20
# 25/25 [==============================] - 7s 262ms/step - loss: 1.4405 - accuracy: 0.4263 - val_loss: 1.5445 - val_accuracy: 0.5250
# Epoch 15/20
# 25/25 [==============================] - 6s 239ms/step - loss: 1.3903 - accuracy: 0.4550 - val_loss: 1.5771 - val_accuracy: 0.4700
# Epoch 16/20
# 25/25 [==============================] - 7s 260ms/step - loss: 1.3199 - accuracy: 0.5337 - val_loss: 1.4418 - val_accuracy: 0.5550
# Epoch 17/20
# 25/25 [==============================] - 6s 239ms/step - loss: 1.2793 - accuracy: 0.5350 - val_loss: 1.3510 - val_accuracy: 0.4700
# Epoch 18/20
# 25/25 [==============================] - 6s 239ms/step - loss: 1.3854 - accuracy: 0.5050 - val_loss: 1.4312 - val_accuracy: 0.5100
# Epoch 19/20
# 25/25 [==============================] - 6s 239ms/step - loss: 1.2039 - accuracy: 0.5500 - val_loss: 1.3778 - val_accuracy: 0.4950
# Epoch 20/20
# 25/25 [==============================] - 6s 238ms/step - loss: 1.1835 - accuracy: 0.5575 - val_loss: 1.2570 - val_accuracy: 0.5900

# %% [markdown]
# #Evaluación del modelo
#
# Sobre datos test
