# %% [markdown]
# # Regresión

# %% [markdown]
# # Librerías

# %%
from tensorflow.keras.datasets import boston_housing

# %% [markdown]
# # Dataset
#
# *   Etiquetas: precio estimado
# *   404 muestras de entrenamiento
# *   102 muestras de test
# *   Escala de los features diferente
# *   Precios de vivienda a mediados de los 70 en miles de dólares
#
# https://www.kaggle.com/c/boston-housing
#
# https://github.com/selva86/datasets/tree/master

# %%
(train_data, train_targets), (test_data, test_targets) = (boston_housing.load_data())

# Ver shape
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
# Etiquetas

train_targets
# Out:
# array([15.2, 42.3, 50. , 21.1, 17.7, 18.5, 11.3, 15.6, 15.6, 14.4, 12.1,
#        17.9, 23.1, 19.9, 15.7,  8.8, 50. , 22.5, 24.1, 27.5, 10.9, 30.8,
#        32.9, 24. , 18.5, 13.3, 22.9, 34.7, 16.6, 17.5, 22.3, 16.1, 14.9,
#        23.1, 34.9, 25. , 13.9, 13.1, 20.4, 20. , 15.2, 24.7, 22.2, 16.7,
#        12.7, 15.6, 18.4, 21. , 30.1, 15.1, 18.7,  9.6, 31.5, 24.8, 19.1,
#        22. , 14.5, 11. , 32. , 29.4, 20.3, 24.4, 14.6, 19.5, 14.1, 14.3,
#        15.6, 10.5,  6.3, 19.3, 19.3, 13.4, 36.4, 17.8, 13.5, 16.5,  8.3,
#        14.3, 16. , 13.4, 28.6, 43.5, 20.2, 22. , 23. , 20.7, 12.5, 48.5,
#        14.6, 13.4, 23.7, 50. , 21.7, 39.8, 38.7, 22.2, 34.9, 22.5, 31.1,
#        28.7, 46. , 41.7, 21. , 26.6, 15. , 24.4, 13.3, 21.2, 11.7, 21.7,
#        19.4, 50. , 22.8, 19.7, 24.7, 36.2, 14.2, 18.9, 18.3, 20.6, 24.6,
#        18.2,  8.7, 44. , 10.4, 13.2, 21.2, 37. , 30.7, 22.9, 20. , 19.3,
#        31.7, 32. , 23.1, 18.8, 10.9, 50. , 19.6,  5. , 14.4, 19.8, 13.8,
# ...

# %%
# Normalizar los datos (feature-wise normalization)
# for each feature in the input data (a column in the input data matrix), we
# subtract the mean of the feature and divide by the standard deviation

mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std

test_data -= mean
test_data /= std

# %%
from tensorflow import keras
from tensorflow.keras import layers

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Conv2D, Dense, MaxPooling2D

from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# # Modelo
#
# *   No. de capas
# *   Neuronas por capa

# %%
def build_model():
  model = Sequential([
    Dense(64, activation="relu"),
    Dense(128, activation="relu"),
    Dense(1)
  ])

  model.compile(
      optimizer="rmsprop",
      loss="mse",
      metrics=["mae"])
  return model

# %% [markdown]
# # Entrenamiento modelo final

# %%
model = build_model()
history = model.fit(train_data, train_targets,
epochs=130, batch_size=16, verbose=0)
test_mse_score, test_mae_score = model.evaluate(test_data, test_targets)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 14.5472 - mae: 2.5629

# %%
test_mae_score

# Try varying the number of layers in the model
# Try varying the number of units per layer
# Out:
# 2.501981258392334

# %% [markdown]
# # Plot

# %% [markdown]
# # Predicciones

# %%
predictions = model.predict(test_data)
predictions[0]
# Out:
# 4/4 [==============================] - 0s 3ms/step
# array([8.900263], dtype=float32)

# %% [markdown]
# # Referencias
#
# https://www.kaggle.com/c/boston-housing
#
# https://github.com/selva86/datasets/tree/master
#
# Deep Learning with Python, second edition, François Chollet,
# Manning Publications Co, 2021
