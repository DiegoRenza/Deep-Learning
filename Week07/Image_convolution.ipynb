# %%
# !install cv2

import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("Building.jpg")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

filtro_horizontal = np.array([
    [-1, -2, -1],
    [ 0,  0,  0],
    [ 1,  2,  1]
])

horizontal = cv2.filter2D(image, -1, filtro_horizontal)

plt.subplot(2, 2, 1), plt.imshow(image)
plt.subplot(2, 2, 2), plt.imshow(horizontal_edges)

plt.setp(plt.gcf().get_axes(), xticks=[], yticks=[])
# Out:
# install: missing destination file operand after 'cv2'
# Try 'install --help' for more information.
# []

# %%
filtro_vertical =np.array([
    [-1, 0, 1],
    [-2, 0, 2],
    [-1, 0, 1]
])

filtro_diagonal = np.array([
    [-1, -2, 0],
    [-2, 0, 2],
    [0, 2, 1]
])

vertical = cv2.filter2D(image, -1, filtro_vertical)
diagonal_edges2 = cv2.filter2D(image, -1, filtro_diagonal)


plt.subplot(2, 2, 3), plt.imshow(vertical_edges)
plt.subplot(2, 2, 4), plt.imshow(diagonal_edges2)
