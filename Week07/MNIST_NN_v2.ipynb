# %% [markdown]
# # **DEEP LEARNING**
#
# **UNIVERSIDAD MILITAR NUEVA GRANADA**
#
# **DEEP LEARNING - PERCEPTRON MULTICAPA**
#
# Ingeniería en Telecomunicaciones

# %%
# Carga de librerías
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Carga de módulos
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

# %% [markdown]
# # Dataset
#
# MNIST dataset

# %%
# Carga
(x_train , y_train ), (x_test , y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28)
# (60000,) (10000,)

# %%
# Reshape a tensor
x_train = x_train.reshape( (x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape( (x_test.shape[0], 28, 28, 1))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
# One-hot-encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 10)
# (10000, 10)

# %% [markdown]
# # Modelos

# %%
# Modelo NN FC

# Hiperparámetros
batch_s, lr, num_epochs = 32, 0.01, 10
optimizerf = tf.keras.optimizers.SGD(learning_rate=lr)

# Modelo
model = Sequential([
                    Flatten(),  # 28*28*1=784
                    Dense(256, activation='relu'),
                    Dense(10, activation='softmax')
])

# %%
# Modelo 2 CNN

# Hiperparámetros
batch_s, lr, num_epochs = 32, 0.01, 10
optimizerf = tf.keras.optimizers.SGD(learning_rate=lr)

# Modelo
model = Sequential([
                    Conv2D(32, (3, 3),
                           activation= 'relu',
                           input_shape=(28, 28, 1)
                           ),
                    MaxPooling2D((2, 2)),
                    Flatten(),
                    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Compilación y entrenamiento del modelo

# %%
model.compile(
  optimizer=optimizerf,
  loss= 'categorical_crossentropy',
  metrics=['CategoricalAccuracy']
)

# %% [markdown]
# # Entrenamiento

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=num_epochs,
    batch_size=batch_s,
    validation_data=(x_test, y_test)
    )
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - CategoricalAccuracy: 0.7687 - loss: 0.8955 - val_CategoricalAccuracy: 0.9098 - val_loss: 0.3135
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - CategoricalAccuracy: 0.9101 - loss: 0.3095 - val_CategoricalAccuracy: 0.9215 - val_loss: 0.2743
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - CategoricalAccuracy: 0.9171 - loss: 0.2887 - val_CategoricalAccuracy: 0.9253 - val_loss: 0.2556
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - CategoricalAccuracy: 0.9254 - loss: 0.2607 - val_CategoricalAccuracy: 0.9355 - val_loss: 0.2234
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - CategoricalAccuracy: 0.9332 - loss: 0.2292 - val_CategoricalAccuracy: 0.9455 - val_loss: 0.1944
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - CategoricalAccuracy: 0.9436 - loss: 0.1995 - val_CategoricalAccuracy: 0.9516 - val_loss: 0.1684
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - CategoricalAccuracy: 0.9534 - loss: 0.1679 - val_CategoricalAccuracy: 0.9589 - val_loss: 0.1479
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - CategoricalAccuracy: 0.9592 - loss: 0.1474 - val_CategoricalAccuracy: 0.9610 - val_loss: 0.1320
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - CategoricalAccuracy: 0.9654 - loss: 0.1278 - val_CategoricalAccuracy: 0.9666 - val_loss: 0.1160
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - CategoricalAccuracy: 0.9687 - loss: 0.1203 - val_CategoricalAccuracy: 0.9689 - val_loss: 0.1073

# %%
# No. de parámetros en una capa FC:
# No. unidades capa entrada * No. unidades capa salida + No. unidades capa salida (bias)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 5408)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │          54,090 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 54,412 (212.55 KB)
#  Trainable params: 54,410 (212.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
